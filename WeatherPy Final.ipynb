# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)


# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 591

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = 'https://api.openweathermap.org/data/2.5/weather?'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}"
    
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | skelleftea
# Processing Record 3 of Set 1 | margaret river
# Processing Record 4 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 5 of Set 1 | waterville
# Processing Record 6 of Set 1 | bikenibeu village
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | sitka
# Processing Record 11 of Set 1 | college
# Processing Record 12 of Set 1 | haiku-pauwela
# Processing Record 13 of Set 1 | invercargill
# Processing Record 14 of Set 1 | waitangi
# Processing Record 15 of Set 1 | tazacorte
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | aras-asan
# Processing Record 18 of Set 1 | taroa
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | box elder
# Processing Record 21 of Set 1 | saldanha
# Processing Record 22 of Set 1 | teofilo otoni
# Processing Record 23 of Set 1 | mont-dore
# Processing Record 24 of Set 1 | vorozhba
# Processing Record 25 of Set 1 | nogliki
# Processing Record 26 of Set 1 | hauterive
# Processing Record 27 of Set 1 | talnakh
# Processing Record 28 of Set 1 | geraldton
# Processing Record 29 of Set 1 | edinburgh of the seven seas
# Processing Record 30 of Set 1 | argo
# Processing Record 31 of Set 1 | laojunmiao
# Processing Record 32 of Set 1 | udachny
# Processing Record 33 of Set 1 | iqaluit
# Processing Record 34 of Set 1 | hamilton
# Processing Record 35 of Set 1 | srpska crnja
# Processing Record 36 of Set 1 | valparaiso
# Processing Record 37 of Set 1 | igarka
# Processing Record 38 of Set 1 | namibe
# Processing Record 39 of Set 1 | grytviken
# Processing Record 40 of Set 1 | kargat
# Processing Record 41 of Set 1 | blackmans bay
# Processing Record 42 of Set 1 | nuuk
# Processing Record 43 of Set 1 | katsuura
# Processing Record 44 of Set 1 | nay pyi taw
# Processing Record 45 of Set 1 | ijuw
# City not found. Skipping...
# Processing Record 46 of Set 1 | gubkinskiy
# Processing Record 47 of Set 1 | danilovka
# Processing Record 48 of Set 1 | keflavik
# Processing Record 49 of Set 1 | kalix
# Processing Record 50 of Set 1 | coquimbo
# Processing Record 0 of Set 2 | nar'yan-mar
# Processing Record 1 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 2 of Set 2 | kayangel
# Processing Record 3 of Set 2 | clifton
# Processing Record 4 of Set 2 | arkhara
# Processing Record 5 of Set 2 | sinabang
# Processing Record 6 of Set 2 | port blair
# Processing Record 7 of Set 2 | hawaiian paradise park
# Processing Record 8 of Set 2 | batie
# Processing Record 9 of Set 2 | ust-nera
# Processing Record 10 of Set 2 | kapuskasing
# Processing Record 11 of Set 2 | shorapur
# Processing Record 12 of Set 2 | al bawiti
# Processing Record 13 of Set 2 | gadzhiyevo
# Processing Record 14 of Set 2 | romblon
# Processing Record 15 of Set 2 | west island
# Processing Record 16 of Set 2 | illizi
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | greymouth
# Processing Record 19 of Set 2 | sao joao da barra
# Processing Record 20 of Set 2 | tolanaro
# Processing Record 21 of Set 2 | galliano
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | yaren
# Processing Record 24 of Set 2 | klyuchi
# Processing Record 25 of Set 2 | lerwick
# Processing Record 26 of Set 2 | luderitz
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | punta arenas
# Processing Record 29 of Set 2 | bethel
# Processing Record 30 of Set 2 | meulaboh
# Processing Record 31 of Set 2 | fortuna
# Processing Record 32 of Set 2 | stanley
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | sanctuary point
# Processing Record 35 of Set 2 | dhidhdhoo
# Processing Record 36 of Set 2 | erenhot
# Processing Record 37 of Set 2 | lodwar
# Processing Record 38 of Set 2 | lulea
# Processing Record 39 of Set 2 | playa del ingles
# Processing Record 40 of Set 2 | nelson bay
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | celestun
# Processing Record 43 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 44 of Set 2 | abraham's bay
# City not found. Skipping...
# Processing Record 45 of Set 2 | georgetown
# Processing Record 46 of Set 2 | dudinka
# Processing Record 47 of Set 2 | clarksburg
# Processing Record 48 of Set 2 | homer
# Processing Record 49 of Set 2 | yuzhno-kurilsk
# Processing Record 0 of Set 3 | whitehorse
# Processing Record 1 of Set 3 | constantia
# Processing Record 2 of Set 3 | sabang
# Processing Record 3 of Set 3 | iskateley
# Processing Record 4 of Set 3 | sinan
# Processing Record 5 of Set 3 | port alfred
# Processing Record 6 of Set 3 | fort bragg
# Processing Record 7 of Set 3 | kamaishi
# Processing Record 8 of Set 3 | olonkinbyen
# Processing Record 9 of Set 3 | mohelnice
# Processing Record 10 of Set 3 | tarancon
# Processing Record 11 of Set 3 | nishinoomote
# Processing Record 12 of Set 3 | afaahiti
# Processing Record 13 of Set 3 | saipan
# Processing Record 14 of Set 3 | ugoofaaru
# Processing Record 15 of Set 3 | mirnyy
# Processing Record 16 of Set 3 | karachi
# Processing Record 17 of Set 3 | ma'ili
# Processing Record 18 of Set 3 | palu
# Processing Record 19 of Set 3 | greenville
# Processing Record 20 of Set 3 | rujiena
# Processing Record 21 of Set 3 | tadine
# Processing Record 22 of Set 3 | puerto natales
# Processing Record 23 of Set 3 | lebork
# Processing Record 24 of Set 3 | road town
# Processing Record 25 of Set 3 | utrik
# Processing Record 26 of Set 3 | qingyuan
# Processing Record 27 of Set 3 | sinop
# Processing Record 28 of Set 3 | lashio
# Processing Record 29 of Set 3 | sao jose da coroa grande
# Processing Record 30 of Set 3 | mkushi
# Processing Record 31 of Set 3 | st. john's
# Processing Record 32 of Set 3 | puerto ayora
# Processing Record 33 of Set 3 | kone
# Processing Record 34 of Set 3 | aasiaat
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | sisimiut
# Processing Record 37 of Set 3 | itoman
# Processing Record 38 of Set 3 | salalah
# Processing Record 39 of Set 3 | martil
# Processing Record 40 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 41 of Set 3 | santa cruz de tenerife
# Processing Record 42 of Set 3 | lubang
# Processing Record 43 of Set 3 | ilebo
# Processing Record 44 of Set 3 | puerto leguizamo
# Processing Record 45 of Set 3 | chul'man
# Processing Record 46 of Set 3 | bikaner
# Processing Record 47 of Set 3 | bereznik
# Processing Record 48 of Set 3 | broome
# Processing Record 49 of Set 3 | inari
# Processing Record 0 of Set 4 | pohang
# Processing Record 1 of Set 4 | atafu village
# Processing Record 2 of Set 4 | thompson
# Processing Record 3 of Set 4 | fort st. john
# Processing Record 4 of Set 4 | papatowai
# Processing Record 5 of Set 4 | avarua
# Processing Record 6 of Set 4 | alice springs
# Processing Record 7 of Set 4 | nemuro
# Processing Record 8 of Set 4 | tura
# Processing Record 9 of Set 4 | touros
# Processing Record 10 of Set 4 | rio tuba
# Processing Record 11 of Set 4 | mugia
# Processing Record 12 of Set 4 | banfora
# Processing Record 13 of Set 4 | nova vicosa
# Processing Record 14 of Set 4 | santa cruz
# Processing Record 15 of Set 4 | ma'rib
# Processing Record 16 of Set 4 | ancud
# Processing Record 17 of Set 4 | taguatinga
# Processing Record 18 of Set 4 | mount pearl
# Processing Record 19 of Set 4 | copala
# Processing Record 20 of Set 4 | la carlota
# Processing Record 21 of Set 4 | nova sintra
# Processing Record 22 of Set 4 | sandy point town
# Processing Record 23 of Set 4 | hermanus
# Processing Record 24 of Set 4 | fale old settlement
# Processing Record 25 of Set 4 | chichli
# Processing Record 26 of Set 4 | jamestown
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | port mathurin
# Processing Record 29 of Set 4 | maxixe
# Processing Record 30 of Set 4 | dom pedro
# Processing Record 31 of Set 4 | maraba
# Processing Record 32 of Set 4 | qaqortoq
# Processing Record 33 of Set 4 | crane
# Processing Record 34 of Set 4 | port saint john's
# Processing Record 35 of Set 4 | east end
# Processing Record 36 of Set 4 | isafjordur
# Processing Record 37 of Set 4 | bilibino
# Processing Record 38 of Set 4 | vorgashor
# Processing Record 39 of Set 4 | ilulissat
# Processing Record 40 of Set 4 | bulawayo
# Processing Record 41 of Set 4 | woodward
# Processing Record 42 of Set 4 | alofi
# Processing Record 43 of Set 4 | vilyuysk
# Processing Record 44 of Set 4 | tazovsky
# Processing Record 45 of Set 4 | siem reap
# Processing Record 46 of Set 4 | el charco
# Processing Record 47 of Set 4 | lyozna
# Processing Record 48 of Set 4 | coahuayana de hidalgo
# Processing Record 49 of Set 4 | lauderdale-by-the-sea
# Processing Record 0 of Set 5 | remire-montjoly
# Processing Record 1 of Set 5 | colonia
# Processing Record 2 of Set 5 | wailua homesteads
# Processing Record 3 of Set 5 | cill airne
# Processing Record 4 of Set 5 | kourou
# Processing Record 5 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 6 of Set 5 | walvis bay
# Processing Record 7 of Set 5 | praia da vitoria
# Processing Record 8 of Set 5 | umm kaddadah
# Processing Record 9 of Set 5 | vila franca do campo
# Processing Record 10 of Set 5 | longyearbyen
# Processing Record 11 of Set 5 | nyurba
# Processing Record 12 of Set 5 | lugovoye
# Processing Record 13 of Set 5 | isangel
# Processing Record 14 of Set 5 | cherry hill
# Processing Record 15 of Set 5 | selfoss
# Processing Record 16 of Set 5 | khovd
# Processing Record 17 of Set 5 | las tablas
# Processing Record 18 of Set 5 | port hedland
# Processing Record 19 of Set 5 | asind
# Processing Record 20 of Set 5 | kavaratti
# Processing Record 21 of Set 5 | cadale
# Processing Record 22 of Set 5 | matveyev kurgan
# Processing Record 23 of Set 5 | luau
# Processing Record 24 of Set 5 | kamuli
# Processing Record 25 of Set 5 | grootfontein
# Processing Record 26 of Set 5 | san julian
# Processing Record 27 of Set 5 | mhamid
# Processing Record 28 of Set 5 | san antonio de pale
# Processing Record 29 of Set 5 | aksuat
# Processing Record 30 of Set 5 | berbera
# Processing Record 31 of Set 5 | priladozhskiy
# Processing Record 32 of Set 5 | barra dos coqueiros
# Processing Record 33 of Set 5 | porto murtinho
# Processing Record 34 of Set 5 | kailua-kona
# Processing Record 35 of Set 5 | kushalgarh
# Processing Record 36 of Set 5 | pisco
# Processing Record 37 of Set 5 | saint-pierre
# Processing Record 38 of Set 5 | kerikeri
# Processing Record 39 of Set 5 | maceio
# Processing Record 40 of Set 5 | jindabyne
# Processing Record 41 of Set 5 | port lincoln
# Processing Record 42 of Set 5 | terrace
# Processing Record 43 of Set 5 | enewetak
# Processing Record 44 of Set 5 | huinan
# Processing Record 45 of Set 5 | letlhakeng
# Processing Record 46 of Set 5 | anserma
# Processing Record 47 of Set 5 | dapa
# Processing Record 48 of Set 5 | papao
# Processing Record 49 of Set 5 | east london
# Processing Record 0 of Set 6 | bardai
# Processing Record 1 of Set 6 | ashland
# Processing Record 2 of Set 6 | masterton
# Processing Record 3 of Set 6 | puerto lempira
# Processing Record 4 of Set 6 | rongelap
# Processing Record 5 of Set 6 | dongsheng
# Processing Record 6 of Set 6 | ghat
# Processing Record 7 of Set 6 | lihue
# Processing Record 8 of Set 6 | hadibu
# Processing Record 9 of Set 6 | kannad
# Processing Record 10 of Set 6 | aksu
# Processing Record 11 of Set 6 | cabo san lucas
# Processing Record 12 of Set 6 | payakumbuh
# Processing Record 13 of Set 6 | glendive
# Processing Record 14 of Set 6 | karratha
# Processing Record 15 of Set 6 | preobrazheniye
# Processing Record 16 of Set 6 | kingston
# Processing Record 17 of Set 6 | kasongo
# Processing Record 18 of Set 6 | talcahuano
# Processing Record 19 of Set 6 | parabel'
# Processing Record 20 of Set 6 | charlottetown
# Processing Record 21 of Set 6 | little cayman
# City not found. Skipping...
# Processing Record 22 of Set 6 | weno
# Processing Record 23 of Set 6 | elesbao veloso
# Processing Record 24 of Set 6 | naze
# Processing Record 25 of Set 6 | dzialdowo
# Processing Record 26 of Set 6 | kankaanpaa
# Processing Record 27 of Set 6 | olenino
# Processing Record 28 of Set 6 | luganville
# Processing Record 29 of Set 6 | bel ombre
# Processing Record 30 of Set 6 | mbala
# Processing Record 31 of Set 6 | kuytun
# Processing Record 32 of Set 6 | cumnock
# Processing Record 33 of Set 6 | uusikaupunki
# Processing Record 34 of Set 6 | la passe
# Processing Record 35 of Set 6 | uturoa
# Processing Record 36 of Set 6 | farasan
# Processing Record 37 of Set 6 | hilo
# Processing Record 38 of Set 6 | neverkino
# Processing Record 39 of Set 6 | griffith
# Processing Record 40 of Set 6 | beloretsk
# Processing Record 41 of Set 6 | gounou gaya
# Processing Record 42 of Set 6 | ingeniero jacobacci
# Processing Record 43 of Set 6 | minas de marcona
# Processing Record 44 of Set 6 | lebu
# Processing Record 45 of Set 6 | codrington
# Processing Record 46 of Set 6 | peniche
# Processing Record 47 of Set 6 | tegueste
# Processing Record 48 of Set 6 | mount pleasant
# Processing Record 49 of Set 6 | san andres
# Processing Record 0 of Set 7 | titao
# Processing Record 1 of Set 7 | kajaani
# Processing Record 2 of Set 7 | sierra grande
# Processing Record 3 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 4 of Set 7 | moree
# Processing Record 5 of Set 7 | posto fiscal rolim de moura
# Processing Record 6 of Set 7 | sernur
# Processing Record 7 of Set 7 | booue
# Processing Record 8 of Set 7 | shemgang
# Processing Record 9 of Set 7 | campbellton
# Processing Record 10 of Set 7 | ringkobing
# Processing Record 11 of Set 7 | saint-louis
# Processing Record 12 of Set 7 | ardakan
# Processing Record 13 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 14 of Set 7 | villa de san diego de ubate
# Processing Record 15 of Set 7 | harstad
# Processing Record 16 of Set 7 | karukh
# Processing Record 17 of Set 7 | souillac
# Processing Record 18 of Set 7 | al ghayzah
# Processing Record 19 of Set 7 | inirida
# Processing Record 20 of Set 7 | bayan nur
# City not found. Skipping...
# Processing Record 21 of Set 7 | tshabong
# Processing Record 22 of Set 7 | beledweyne
# Processing Record 23 of Set 7 | kulia village
# City not found. Skipping...
# Processing Record 24 of Set 7 | soligalich
# Processing Record 25 of Set 7 | nadym
# Processing Record 26 of Set 7 | turkmenbasy
# Processing Record 27 of Set 7 | barakani
# Processing Record 28 of Set 7 | qianzhou
# Processing Record 29 of Set 7 | chonchi
# Processing Record 30 of Set 7 | kangiwa
# Processing Record 31 of Set 7 | pauini
# Processing Record 32 of Set 7 | woods creek
# Processing Record 33 of Set 7 | lorengau
# Processing Record 34 of Set 7 | tibiri
# Processing Record 35 of Set 7 | crateus
# Processing Record 36 of Set 7 | ca mau
# Processing Record 37 of Set 7 | pocone
# Processing Record 38 of Set 7 | emerald
# Processing Record 39 of Set 7 | okha
# Processing Record 40 of Set 7 | ampanihy
# Processing Record 41 of Set 7 | belmonte
# Processing Record 42 of Set 7 | lompoc
# Processing Record 43 of Set 7 | tsiombe
# Processing Record 44 of Set 7 | novyy urgal
# Processing Record 45 of Set 7 | zheleznodorozhnyy
# Processing Record 46 of Set 7 | whakatane
# Processing Record 47 of Set 7 | rach gia
# Processing Record 48 of Set 7 | muzayri'
# City not found. Skipping...
# Processing Record 49 of Set 7 | anadyr
# Processing Record 0 of Set 8 | porto novo
# Processing Record 1 of Set 8 | opuwo
# Processing Record 2 of Set 8 | hastings
# Processing Record 3 of Set 8 | burang
# Processing Record 4 of Set 8 | mgandu
# Processing Record 5 of Set 8 | palikir - national government center
# Processing Record 6 of Set 8 | naha
# Processing Record 7 of Set 8 | bridlington
# Processing Record 8 of Set 8 | huocheng
# City not found. Skipping...
# Processing Record 9 of Set 8 | luanda
# Processing Record 10 of Set 8 | tutoia
# Processing Record 11 of Set 8 | riachao
# Processing Record 12 of Set 8 | yonan-up
# Processing Record 13 of Set 8 | nosy varika
# Processing Record 14 of Set 8 | sanchursk
# Processing Record 15 of Set 8 | guane
# Processing Record 16 of Set 8 | sumbe
# Processing Record 17 of Set 8 | kendari
# Processing Record 18 of Set 8 | vadso
# Processing Record 19 of Set 8 | susuman
# Processing Record 20 of Set 8 | ismailia
# Processing Record 21 of Set 8 | murun-kuren
# Processing Record 22 of Set 8 | oyama
# Processing Record 23 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 24 of Set 8 | gokceada
# Processing Record 25 of Set 8 | kas
# Processing Record 26 of Set 8 | kapa'a
# Processing Record 27 of Set 8 | west bay
# Processing Record 28 of Set 8 | cidreira
# Processing Record 29 of Set 8 | yemetsk
# Processing Record 30 of Set 8 | oriximina
# Processing Record 31 of Set 8 | tofol
# Processing Record 32 of Set 8 | nizwa
# Processing Record 33 of Set 8 | colac
# Processing Record 34 of Set 8 | ataq
# Processing Record 35 of Set 8 | port clinton
# Processing Record 36 of Set 8 | garachico
# Processing Record 37 of Set 8 | upper grand lagoon
# Processing Record 38 of Set 8 | ta`u
# Processing Record 39 of Set 8 | hotan
# Processing Record 40 of Set 8 | le port
# Processing Record 41 of Set 8 | chiredzi
# Processing Record 42 of Set 8 | vohipaho
# City not found. Skipping...
# Processing Record 43 of Set 8 | tongchuanshi
# Processing Record 44 of Set 8 | sumbawa besar
# Processing Record 45 of Set 8 | callao
# Processing Record 46 of Set 8 | leava
# Processing Record 47 of Set 8 | lindisfarne
# Processing Record 48 of Set 8 | verkhnevilyuysk
# Processing Record 49 of Set 8 | selebi-phikwe
# Processing Record 0 of Set 9 | dryden
# Processing Record 1 of Set 9 | saint-francois
# Processing Record 2 of Set 9 | as saffaniyah
# Processing Record 3 of Set 9 | castillos
# Processing Record 4 of Set 9 | vovchans'k
# Processing Record 5 of Set 9 | rurrenabaque
# Processing Record 6 of Set 9 | huarmey
# Processing Record 7 of Set 9 | al qubbah
# Processing Record 8 of Set 9 | corinto
# Processing Record 9 of Set 9 | saint-philippe
# Processing Record 10 of Set 9 | santa isabel
# Processing Record 11 of Set 9 | auki
# Processing Record 12 of Set 9 | vilyuchinsk
# Processing Record 13 of Set 9 | la sarre
# Processing Record 14 of Set 9 | shengli
# Processing Record 15 of Set 9 | north bend
# Processing Record 16 of Set 9 | kittila
# Processing Record 17 of Set 9 | lauro de freitas
# Processing Record 18 of Set 9 | happy valley-goose bay
# Processing Record 19 of Set 9 | gulf shores
# Processing Record 20 of Set 9 | nabire
# Processing Record 21 of Set 9 | labytnangi
# Processing Record 22 of Set 9 | las lomitas
# Processing Record 23 of Set 9 | polovinnoye
# Processing Record 24 of Set 9 | ciudad bolivar
# Processing Record 25 of Set 9 | holualoa
# Processing Record 26 of Set 9 | el granada
# Processing Record 27 of Set 9 | dean funes
# Processing Record 28 of Set 9 | brookings
# Processing Record 29 of Set 9 | ben gardane
# Processing Record 30 of Set 9 | exu
# Processing Record 31 of Set 9 | sandy
# Processing Record 32 of Set 9 | alta
# Processing Record 33 of Set 9 | the quarter
# City not found. Skipping...
# Processing Record 34 of Set 9 | flying fish cove
# Processing Record 35 of Set 9 | north bay
# Processing Record 36 of Set 9 | fortuna foothills
# Processing Record 37 of Set 9 | almeirim
# Processing Record 38 of Set 9 | shingu
# Processing Record 39 of Set 9 | borgarnes
# Processing Record 40 of Set 9 | vernon
# Processing Record 41 of Set 9 | el calafate
# Processing Record 42 of Set 9 | macau
# Processing Record 43 of Set 9 | tchintabaraden
# Processing Record 44 of Set 9 | champerico
# Processing Record 45 of Set 9 | asosa
# Processing Record 46 of Set 9 | gizo
# Processing Record 47 of Set 9 | bengkulu
# Processing Record 48 of Set 9 | prainha
# Processing Record 49 of Set 9 | nsanje
# Processing Record 0 of Set 10 | eastham
# Processing Record 1 of Set 10 | pantai cenang
# City not found. Skipping...
# Processing Record 2 of Set 10 | thunder bay
# Processing Record 3 of Set 10 | skeldon
# Processing Record 4 of Set 10 | fuglafjordur
# Processing Record 5 of Set 10 | gereida
# Processing Record 6 of Set 10 | chagny
# Processing Record 7 of Set 10 | brotas
# Processing Record 8 of Set 10 | karatsu
# Processing Record 9 of Set 10 | tocopilla
# Processing Record 10 of Set 10 | ayod
# City not found. Skipping...
# Processing Record 11 of Set 10 | buka
# Processing Record 12 of Set 10 | cabinda
# Processing Record 13 of Set 10 | palmer
# Processing Record 14 of Set 10 | laguna
# Processing Record 15 of Set 10 | zaozersk
# Processing Record 16 of Set 10 | vila velha
# Processing Record 17 of Set 10 | mukalla
# Processing Record 18 of Set 10 | rio bueno
# Processing Record 19 of Set 10 | nikolayevsk-on-amure
# Processing Record 20 of Set 10 | portland
# Processing Record 21 of Set 10 | san pedro pochutla
# Processing Record 22 of Set 10 | kohima
# Processing Record 23 of Set 10 | tamandare
# Processing Record 24 of Set 10 | nuku'alofa
# Processing Record 25 of Set 10 | baiti
# Processing Record 26 of Set 10 | fiambala
# Processing Record 27 of Set 10 | qarazhal
# Processing Record 28 of Set 10 | tual
# Processing Record 29 of Set 10 | lewistown
# Processing Record 30 of Set 10 | mo i rana
# Processing Record 31 of Set 10 | morondava
# Processing Record 32 of Set 10 | alaghsas
# Processing Record 33 of Set 10 | ouesso
# Processing Record 34 of Set 10 | dunedin
# Processing Record 35 of Set 10 | dingzhou
# Processing Record 36 of Set 10 | yangor
# City not found. Skipping...
# Processing Record 37 of Set 10 | okhotsk
# Processing Record 38 of Set 10 | rio grande
# Processing Record 39 of Set 10 | revda
# Processing Record 40 of Set 10 | lobujya
# Processing Record 41 of Set 10 | san luis de la loma
# Processing Record 42 of Set 10 | kristiansund
# Processing Record 43 of Set 10 | sao felix do xingu
# Processing Record 44 of Set 10 | iowa park
# Processing Record 45 of Set 10 | new norfolk
# Processing Record 46 of Set 10 | ternate
# Processing Record 47 of Set 10 | contamana
# Processing Record 48 of Set 10 | jutai
# Processing Record 49 of Set 10 | stephenville
# Processing Record 0 of Set 11 | gutierrez zamora
# Processing Record 1 of Set 11 | djambala
# Processing Record 2 of Set 11 | boyolangu
# Processing Record 3 of Set 11 | sandnessjoen
# Processing Record 4 of Set 11 | aral
# Processing Record 5 of Set 11 | brisas de zicatela
# Processing Record 6 of Set 11 | lachi
# Processing Record 7 of Set 11 | iturama
# Processing Record 8 of Set 11 | hoxtolgay
# City not found. Skipping...
# Processing Record 9 of Set 11 | arteche
# Processing Record 10 of Set 11 | wamba
# Processing Record 11 of Set 11 | ceerigaabo
# Processing Record 12 of Set 11 | puerto santa
# Processing Record 13 of Set 11 | badger
# Processing Record 14 of Set 11 | al hudaydah
# Processing Record 15 of Set 11 | kantunilkin
# Processing Record 16 of Set 11 | huron
# Processing Record 17 of Set 11 | martapura
# Processing Record 18 of Set 11 | pacific grove
# Processing Record 19 of Set 11 | harrisonburg
# Processing Record 20 of Set 11 | sur
# Processing Record 21 of Set 11 | sidney
# Processing Record 22 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 11 | swakopmund
# Processing Record 24 of Set 11 | mar del plata
# Processing Record 25 of Set 11 | chibougamau
# Processing Record 26 of Set 11 | kruisfontein
# Processing Record 27 of Set 11 | porbandar
# Processing Record 28 of Set 11 | owando
# Processing Record 29 of Set 11 | santa eularia des riu
# Processing Record 30 of Set 11 | manakara
# Processing Record 31 of Set 11 | baotou
# Processing Record 32 of Set 11 | miyanoura
# City not found. Skipping...
# Processing Record 33 of Set 11 | devinuwara
# City not found. Skipping...
# Processing Record 34 of Set 11 | gislaved
# Processing Record 35 of Set 11 | sena madureira
# Processing Record 36 of Set 11 | marudi
# City not found. Skipping...
# Processing Record 37 of Set 11 | pulandian
# Processing Record 38 of Set 11 | fedorovskiy
# Processing Record 39 of Set 11 | vanimo
# Processing Record 40 of Set 11 | sao miguel do araguaia
# Processing Record 41 of Set 11 | akureyri
# Processing Record 42 of Set 11 | ola
# Processing Record 43 of Set 11 | saint-jean-de-monts
# Processing Record 44 of Set 11 | kununurra
# Processing Record 45 of Set 11 | roccella ionica
# Processing Record 46 of Set 11 | as samawah
# Processing Record 47 of Set 11 | chapada dos guimaraes
# Processing Record 48 of Set 11 | acajutla
# Processing Record 49 of Set 11 | ballina
# Processing Record 0 of Set 12 | majie
# Processing Record 1 of Set 12 | forster
# Processing Record 2 of Set 12 | hasaki
# Processing Record 3 of Set 12 | muynoq
# Processing Record 4 of Set 12 | twon-brass
# Processing Record 5 of Set 12 | kiunga
# Processing Record 6 of Set 12 | mejit
# Processing Record 7 of Set 12 | saint croix
# Processing Record 8 of Set 12 | lae
# Processing Record 9 of Set 12 | mana
# Processing Record 10 of Set 12 | cargados carajos
# City not found. Skipping...
# Processing Record 11 of Set 12 | kinablangan
# Processing Record 12 of Set 12 | tocache
# Processing Record 13 of Set 12 | ankazobe
# Processing Record 14 of Set 12 | dhoraji
# Processing Record 15 of Set 12 | neya
# Processing Record 16 of Set 12 | romsey
# Processing Record 17 of Set 12 | that phanom
# Processing Record 18 of Set 12 | haizhou
# Processing Record 19 of Set 12 | armacao de buzios
# Processing Record 20 of Set 12 | antofagasta
# Processing Record 21 of Set 12 | buston
# Processing Record 22 of Set 12 | mao
# Processing Record 23 of Set 12 | westport
# Processing Record 24 of Set 12 | al jahra'
# Processing Record 25 of Set 12 | arvin
# Processing Record 26 of Set 12 | pointe aux piments
# Processing Record 27 of Set 12 | neosho
# Processing Record 28 of Set 12 | mogadishu
# Processing Record 29 of Set 12 | warren
# Processing Record 30 of Set 12 | kaohsiung
# Processing Record 31 of Set 12 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 32 of Set 12 | freetown
# Processing Record 33 of Set 12 | conde
# Processing Record 34 of Set 12 | benjamin constant
# Processing Record 35 of Set 12 | nouadhibou
# Processing Record 36 of Set 12 | malaga
# Processing Record 37 of Set 12 | winnemucca
# Processing Record 38 of Set 12 | san patricio
# Processing Record 39 of Set 12 | tanrake village
# City not found. Skipping...
# Processing Record 40 of Set 12 | mezhdurechenskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          564
# Lat           564
# Lng           564
# Max Temp      564
# Humidity      564
# Cloudiness    564
# Wind Speed    564
# Country       564
# Date          564
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             kodiak  57.7900 -152.4072    266.88        42           0
# 1         skelleftea  64.7507   20.9528    275.37       100         100
# 2     margaret river -33.9500  115.0667    288.52        77           0
# 3         waterville  44.5520  -69.6317    274.72        44           0
# 4  bikenibeu village   1.3673  173.1241    303.13        79          40
#
#    Wind Speed Country        Date
# 0        4.12      US  1709328928
# 1        5.14      SE  1709329373
# 2        6.67      AU  1709328665
# 3        5.66      US  1709329374
# 4        3.60      KI  1709328952

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   kodiak  57.7900 -152.4072    266.88        42           0
# 1               skelleftea  64.7507   20.9528    275.37       100         100
# 2           margaret river -33.9500  115.0667    288.52        77           0
# 3               waterville  44.5520  -69.6317    274.72        44           0
# 4        bikenibeu village   1.3673  173.1241    303.13        79          40
#
#          Wind Speed Country        Date
# City_ID
# 0              4.12      US  1709328928
# 1              5.14      SE  1709329373
# 2              6.67      AU  1709328665
# 3              5.66      US  1709329374
# 4              3.60      KI  1709328952

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values, y_values, edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Max Latitude vs. Temperature')
plt.grid(True, alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
y_values = city_data_df['Humidity']

plt.scatter(x_values, y_values, edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs.Humidity')
plt.grid(True, alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
y_values = city_data_df['Cloudiness']


plt.scatter(x_values, y_values, edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs.Cloudiness')
plt.grid(True, alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
y_values = city_data_df['Wind Speed']

plt.scatter(x_values, y_values, edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs.Wind Speed')
plt.grid(True, alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lineRegression():
    (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept

    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, 'r-')
    plt.xlabel('Latitude')
    plt.annotate(line_eq,(20,5), fontsize = 15, color = 'red')
    print(f"The r-value is: {rvalue**2}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   kodiak  57.7900 -152.4072    266.88        42           0
# 1               skelleftea  64.7507   20.9528    275.37       100         100
# 3               waterville  44.5520  -69.6317    274.72        44           0
# 4        bikenibeu village   1.3673  173.1241    303.13        79          40
# 8                    sitka  57.0531 -135.3300    274.09        47           0
#
#          Wind Speed Country        Date
# City_ID
# 0              4.12      US  1709328928
# 1              5.14      SE  1709329373
# 3              5.66      US  1709329374
# 4              3.60      KI  1709328952
# 8              7.20      US  1709328799

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City     Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           margaret river -33.950  115.0667    288.52        77           0
# 5                adamstown -25.066 -130.1015    299.24        75          68
# 6                  ushuaia -54.800  -68.3000    284.96        71          75
# 7        port-aux-francais -49.350   70.2167    277.81        72          24
# 11            invercargill -46.400  168.3500    288.16        97          38
#
#          Wind Speed Country        Date
# City_ID
# 2              6.67      AU  1709328665
# 5              2.48      PN  1709328807
# 6              4.63      AR  1709328635
# 7             17.26      TF  1709328621
# 11             1.34      NZ  1709328630

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
plt.ylabel('Max Temperature (C)')
lineRegression()
# Out:
# The r-value is: 0.6870621544071022

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
plt.ylabel('Max Temp')
lineRegression()
# Out:
# The r-value is: 0.4023451112349184

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
plt.ylabel('Humidity')
lineRegression()
# Out:
# The r-value is: 0.10463622461538079

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
plt.ylabel('Humidity')
lineRegression()
# Out:
# The r-value is: 0.09465999879640277

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
plt.ylabel('cloudiness')
lineRegression()
# Out:
# The r-value is: 0.015353032580677151

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
plt.ylabel('Cloudiness')
lineRegression()
# Out:
# The r-value is: 0.03161152982087117

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
plt.ylabel('Wind Speed')
lineRegression()
# Out:
# The r-value is: 0.004691409948225432

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
plt.ylabel('Wind Speed')
lineRegression()
# Out:
# The r-value is: 0.14273970989237317

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
